# %%
import pandas as pd
import csv
from loader import *
from pair_finder import *
import time
from random import seed
import keyboard
from random import seed
from random import randint
import math

# %%
ratings_path_s = "DATA\\ratings.csv"
ratings_path = "DATA\\ratings_100users.csv"
movies_path =  "DATA\\movies.csv"

MinScore = 4
MaxCombo = 4
MinFrequency = 0.1
#ratings_stream = createRatingsStream(ratings_path_s, MinScore)
userBaskets, movie_list = CreateMovieBaskets(ratings_path, MinScore, 1000)
movies_df = ReadMovies(movies_path, movie_list)

# %%
myApriori = myApriori(userBaskets, MinFrequency, MaxCombo)
#c_combos = export_combos(myApriori)
#s_combos = sampledApriori(100, ratings_stream, MinFrequency, MaxCombo)
#print(get_scores(c_combos, s_combos))
# Out:
# 1 ---------------------> 140
# 2 ---------------------> 509
# 3 ---------------------> 629
# 4 ---------------------> 368

# %%
x4 = myApriori[4][frozenset([260, 296, 1210, 2571])]
x3_1 = myApriori[3][frozenset([260, 296, 1210])]
x3_2 = myApriori[3][frozenset([296, 1210, 2571])]
x3_3 = myApriori[3][frozenset([260, 1210, 2571])]
x3_4 = myApriori[3][frozenset([260, 296, 2571])]
x2_1 = myApriori[2][frozenset([260, 296])]
x2_2 = myApriori[2][frozenset([260, 1210])]
x2_3 = myApriori[2][frozenset([260, 2571])]
x2_4 = myApriori[2][frozenset([296, 1210])]
x2_5 = myApriori[2][frozenset([296, 2571])]
x2_6 = myApriori[2][frozenset([1210, 2571])]
x1_1 = myApriori[1][frozenset([260])]
x1_2 = myApriori[1][frozenset([296])]
x1_3 = myApriori[1][frozenset([1210])]
x1_4 = myApriori[1][frozenset([2571])]

# %%
print(x4)
print(x3_4)
print(x3_2)
print(x3_3)
print(x3_4)

print(x2_1)
print(x2_2)
print(x2_3)
print(x2_4)
print(x2_5)
print(x2_6)

print(x1_1)
print(x1_2)
print(x1_3)
print(x1_4)
# Out:
# {'frequency': 0.12, 'baskets': [14, 16, 17, 27, 38, 41, 44, 61, 68, 71, 90, 95]}
# {'frequency': 0.13, 'baskets': [14, 16, 17, 27, 38, 41, 44, 61, 68, 71, 75, 90, 95]}
# {'frequency': 0.13, 'baskets': [14, 16, 17, 27, 32, 38, 41, 44, 61, 68, 71, 90, 95]}
# {'frequency': 0.22, 'baskets': [0, 14, 16, 17, 20, 27, 29, 38, 41, 44, 51, 56, 61, 67, 68, 71, 76, 78, 85, 90, 94, 95]}
# {'frequency': 0.13, 'baskets': [14, 16, 17, 27, 38, 41, 44, 61, 68, 71, 75, 90, 95]}
# {'frequency': 0.16, 'baskets': [14, 16, 17, 27, 31, 38, 41, 44, 61, 62, 68, 71, 75, 83, 90, 95]}
# {'frequency': 0.27, 'baskets': [0, 6, 14, 16, 17, 20, 26, 27, 29, 38, 41, 43, 44, 51, 56, 61, 62, 67, 68, 71, 76, 78, 83, 85, 90, 94, 95]}
# {'frequency': 0.25, 'baskets': [0, 14, 16, 17, 18, 20, 24, 27, 29, 38, 41, 44, 51, 56, 61, 67, 68, 71, 75, 76, 78, 85, 90, 94, 95]}
# {'frequency': 0.15, 'baskets': [14, 16, 17, 27, 32, 38, 41, 44, 61, 62, 68, 71, 83, 90, 95]}
# ...

# %%
def get_scores(itemset_f, hypothesis_f, conclusion_f):
    confidence = get_confidence(itemset_f, hypothesis_f)
    lift = get_lift(confidence, conclusion_f)
    interest = get_interest(confidence, conclusion_f)

    return confidence, lift, interest


def get_confidence(itemset_f, hypothesis_f):
    return itemset_f / hypothesis_f


def get_lift(rule_confidence, conclusion_f):
    return rule_confidence / conclusion_f


def get_interest(rule_confidence, conclusion_f):
    return rule_confidence - conclusion_f

# %%
print(get_scores(x4['frequency'], x3_2['frequency'], x1_1['frequency']))


print(get_scores(x4['frequency'], x2_4['frequency'], x2_3['frequency']))
print(get_scores(x4['frequency'], x2_5['frequency'], x2_2['frequency']))
print("\n")
print(get_scores(x4['frequency'], x1_4['frequency'], x3_1['frequency']))
print("\n")
print(get_scores(x4['frequency'], x2_6['frequency'], x2_1['frequency']))
# Out:
# (0.923076923076923, 2.4948024948024945, 0.553076923076923)
# (0.8, 3.2, 0.55)
# (0.631578947368421, 2.3391812865497075, 0.361578947368421)
#
#
# (0.32432432432432434, 2.3166023166023164, 0.18432432432432433)
#
#
# (0.48, 3.0, 0.31999999999999995)

# %%
def next_hypothesis(current, final):
    h_size = len(current)
    pointer = h_size - 1
    if current == final:
        print("Already at final hypothesis!!")
        return -1
    #print(h_size)
    while True:
        if current[pointer] != final[pointer]:
        
            current[pointer] += 1
            for i in range(pointer + 1, h_size):
                current[i] = current[i-1] + 1
            break
        else:
            pointer -= 1


def get_confidence(itemset_f, hypothesis_f):
    return itemset_f / hypothesis_f


def get_lift(rule_confidence, conclusion_f):
    return rule_confidence / conclusion_f


def get_interest(rule_confidence, conclusion_f):
    return rule_confidence - conclusion_f

# %%
# PRODUCES THE HALF SIZE-COMBINATIONS
# FOR THE CURRENT SET
# THE OTHER HALF ARE SYMMETRIC
MinConfidence = 0.5

rules = {}
rule_id = 1
for k in range(2, MaxCombo + 1):
    rules[k] = []
    combo_size = k
    even_size = (combo_size % 2) == 0
    mid = math.ceil(combo_size / 2)

    for i in range(1, k):
        #rules[k][i] = []
        final_hypothesis =  list(range(combo_size - i, combo_size))
        current_hypothesis = list(range(i))
         
        while True:
            for combo in myApriori[k].keys():
                itemset = sorted(list(combo))
                hypothesis = frozenset([itemset[i] for i in current_hypothesis])
                conclusion = combo.difference(hypothesis)
                frequency = myApriori[k][combo]['frequency']
                confidence = get_confidence(frequency, myApriori[i][hypothesis]['frequency'])
                lift = get_lift(confidence, myApriori[k-i][conclusion]['frequency'])
                interest = get_interest(confidence, myApriori[k-i][conclusion]['frequency'])
                if confidence >= MinConfidence:
                    l_h = sorted(list(hypothesis))
                    l_c = sorted(list(conclusion))
                    tmp_rule = {
                        'itemset': itemset,
                        'rule': f"{l_h}-->{l_c}",
                        'hypothesis': l_h,
                        'conclusion': l_c,
                        'frequency': frequency,
                        'confidence': confidence,
                        'lift': lift,
                        'interest': interest,
                        'rule_ID': rule_id
                    }
                    rules[k].append(tmp_rule)
                    rule_id += 1

            if next_hypothesis(current_hypothesis, final_hypothesis) == -1:
                break
# Out:
# Already at final hypothesis!!
# Already at final hypothesis!!
# Already at final hypothesis!!
# Already at final hypothesis!!
# Already at final hypothesis!!
# Already at final hypothesis!!

# %%
tmp = [1,2,3,4,5,6]
t_size = 6

l1 = list(range(1,t_size))
l2 = list(range(t_size-1))
for i in range(t_size-2, 0, -1):
    print(i)
# Out:
# 4
# 3
# 2
# 1

# %%
rules
# Out:
# {1: [{'hypothesis': frozenset({'A'}),
#    'conclusion': frozenset({'B', 'C', 'D', 'E'})},
#   {'hypothesis': frozenset({'B'}),
#    'conclusion': frozenset({'A', 'C', 'D', 'E'})},
#   {'hypothesis': frozenset({'C'}),
#    'conclusion': frozenset({'A', 'B', 'D', 'E'})},
#   {'hypothesis': frozenset({'D'}),
#    'conclusion': frozenset({'A', 'B', 'C', 'E'})},
#   {'hypothesis': frozenset({'E'}),
#    'conclusion': frozenset({'A', 'B', 'C', 'D'})}],
#  2: [{'hypothesis': frozenset({'A', 'B'}),
#    'conclusion': frozenset({'C', 'D', 'E'})},
#   {'hypothesis': frozenset({'A', 'C'}),
#    'conclusion': frozenset({'B', 'D', 'E'})},
#   {'hypothesis': frozenset({'A', 'D'}),
#    'conclusion': frozenset({'B', 'C', 'E'})},
#   {'hypothesis': frozenset({'A', 'E'}),
#    'conclusion': frozenset({'B', 'C', 'D'})},
#   {'hypothesis': frozenset({'B', 'C'}),
#    'conclusion': frozenset({'A', 'D', 'E'})},
#   {'hypothesis': frozenset({'B', 'D'}),
#    'conclusion': frozenset({'A', 'C', 'E'})},
# ...

# %%
current = [0,1,2]
final = [2,3,4]

count = 0
while next_hypothesis(current, final) != -1:
    print(current)
    count += 1
    print(count)
# Out:
# [0, 1, 3]
# 1
# [0, 1, 4]
# 2
# [0, 2, 3]
# 3
# [0, 2, 4]
# 4
# [0, 3, 4]
# 5
# [1, 2, 3]
# 6
# [1, 2, 4]
# 7
# [1, 3, 4]
# 8
# [2, 3, 4]
# 9
# Already at final hypothesis!!

# %%
for i in range(9,-1, -1):
    print(i)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %% [markdown]
# STORING DATA EXAMPLE

# %%
import pandas as pd
dict_2 = {
    'itemset': '(a,b)',
    'rule': 'a-->b',
    'hypothesis': 'a',
    'conclusion': 'b',
    'confidence': 0.1,
    'lift': 1.0,
    'interest': 0.2,
    'rule_ID': 2
}
df2 = pd.DataFrame(dict_2, index=[0])
df2
