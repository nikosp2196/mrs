# %%
import pandas as pd
import csv

# %%
ratings_path = "DATA\\ratings_100users.csv"
movies_path =  "DATA\\movies.csv"

MinScore = 0 # CHANGE THIS TO USER INPUT

# %%
def CreateMovieBaskets(r_path):
    userBaskets = []
    movies = []
    with open(r_path) as infile:
        ratings_reader = csv.reader(infile, delimiter=',')

        next(ratings_reader)
        current_userId = 0
        for i in ratings_reader:
            userId, movieId, rating = int(i[0]), int(i[1]), float(i[2])

            if current_userId != userId:
                userBaskets.append([])
                current_userId = userId

            if rating >= MinScore:
                userBaskets[-1].append(movieId)
                movies.append(movieId)
        
        return userBaskets, list(set(movies))


def ReadMovies(m_path):
    movies_df = pd.read_csv(m_path)
    movies_df['genres'] = [i.split(sep="|") for i in movies_df['genres']]
    print(movies_df.head())

    return movies_df

# %%
movies_df = ReadMovies(movies_path)
UserBaskets,movies_list = CreateMovieBaskets(ratings_path)
print(len(movies_list))
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                               genres
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]
# 4180

# %%
movies_df.shape
# Out:
# (9742, 3)

# %%
# Keep only the movies that we've found in our baskets and reset the index
movies_df = movies_df[movies_df['movieId'].isin(movies_list)].reset_index(drop=True)
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                               genres
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]

# %%
movies_df.shape
# Out:
# (4180, 3)

# %%
x = movies_df[movies_df['movieId'] == 6].index[0] # Get the index of a specific movieId
x
# Out:
# 4

# %%
x = ['A', 'B', 'C', 'D']
results = []

# %%
import time
start_time = time.time()

results = {}
visited = []
x = ['A', 'B', 'C', 'D']
def get_combo(listR):
    combo_key = ",".join(str(e) for e in listR)
    
    if combo_key not in results.keys():
        results[combo_key] = 0
        
    if combo_key not in visited:
        visited.append(combo_key)
        results[combo_key] += 1
    
    if len(listR) > 3:
        #print(listR)
        #results.append(listR)
        for i in range(len(listR)):
            tmp = listR.copy()
            tmp.pop(i)
            #print("Initial: ", listR,"Pop: ",i, "Result",tmp)
            get_combo(tmp)

for i,b in enumerate(UserBaskets):
    print("Basket ",i,"/",len(UserBaskets))
    get_combo(b)
    visited.clear()

print("--- %s seconds ---" % (time.time() - start_time))
print(len(results.keys()))
print(max(results.items(), key=operator.itemgetter(1))[0])
# Out:
# Basket  0 / 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-97987f03835a> in <module>
#      26 for i,b in enumerate(UserBaskets):
#      27     print("Basket ",i,"/",len(UserBaskets))
# ---> 28     get_combo(b)
#      29     visited.clear()
#      30
#
# <ipython-input-36-97987f03835a> in get_combo(listR)
#      22             tmp.pop(i)
#      23             #print("Initial: ", listR,"Pop: ",i, "Result",tmp)
# ---> 24             get_combo(tmp)
#      25
#      26 for i,b in enumerate(UserBaskets):
#
# <ipython-input-36-97987f03835a> in get_combo(listR)
#      22             tmp.pop(i)
#      23             #print("Initial: ", listR,"Pop: ",i, "Result",tmp)
# ---> 24             get_combo(tmp)
#      25
#      26 for i,b in enumerate(UserBaskets):
#
# <ipython-input-36-97987f03835a> in get_combo(listR)
#      22             tmp.pop(i)
# ...

# %%
res = 0
for i in range(1,200):
    res += 200 * (200 - i) / 2

# %%
def get_pairs(basket):
    pair_list = []

    for i in range(len(basket)):
        for j in range(i+1, len(basket)):
            pair_list.append((basket[i], basket[j]))

    return pair_list


results = {}
for i in UserBaskets:
    combos = get_pairs(i)
    for j in combos:
        combo_key = ",".join(str(e) for e in listR)
        if combo_key not in results.keys():
            results[combo_key] = 1
        else:
            results[combo_key] += 1

print(len(results.keys()))
for i in results.keys():
    print("Pair: ", i," Frequency: ",results[i])
# Out:
# 1990000.0
